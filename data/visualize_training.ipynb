# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import pandas as pd
# Read the data of 400 epochs x 1k samples run
df = pd.read_csv("neuron_net.csv")

# %%
df.head()
# Out:
#    epoch  loss_train  loss_validation  accuracy_train  accuracy_validation
# 0      1    0.001853         0.000156           0.599               0.5439
# 1      2    0.000992         0.000102           0.753               0.6811
# 2      3    0.000375         0.000096           0.808               0.7211
# 3      4    0.000513         0.000084           0.855               0.7558
# 4      5    0.000674         0.000072           0.876               0.7582

# %%
ax1 = plt.gca()
df.plot(kind='line', x='epoch', y='loss_train', ax=ax1)
df.plot(kind='line', x='epoch', y='loss_validation', ax=ax1)
plt.show()

# %%
ax2 = plt.gca()
df.plot(kind='line', x='epoch', y='accuracy_train', ax=ax2)
df.plot(kind='line', x='epoch', y='accuracy_validation', ax=ax2)
plt.show()

# %%
# Read the data of 30 epochs x 50k samples run
df = pd.read_csv("neuron_net.csv")

# %%
ax3 = plt.gca()
df.plot(kind='line', x='epoch', y='loss_train', ax=ax3)
df.plot(kind='line', x='epoch', y='loss_validation', ax=ax3)
plt.show()

# %%
ax4 = plt.gca()
df.plot(kind='line', x='epoch', y='accuracy_train', ax=ax4)
df.plot(kind='line', x='epoch', y='accuracy_validation', ax=ax4)
plt.show()
